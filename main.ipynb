# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Functions</a></span><ul class="toc-item"><li><span><a href="#1.-Write-a-function-that-returns-the-greater-of-two-numbers" data-toc-modified-id="1.-Write-a-function-that-returns-the-greater-of-two-numbers-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>1. Write a function that returns the greater of two numbers</a></span></li><li><span><a href="#2.-Now-write-a-function-that-returns-the-largest-element-on-a-list" data-toc-modified-id="2.-Now-write-a-function-that-returns-the-largest-element-on-a-list-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>2. Now write a function that returns the largest element on a list</a></span></li><li><span><a href="#3.-Write-a-function-that-sums-all-the-elements-on-a-list" data-toc-modified-id="3.-Write-a-function-that-sums-all-the-elements-on-a-list-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>3. Write a function that sums all the elements on a list</a></span></li><li><span><a href="#4.-Write-another-function-that-multiplies-all-the-elements-on-a-list" data-toc-modified-id="4.-Write-another-function-that-multiplies-all-the-elements-on-a-list-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>4. Write another function that multiplies all the elements on a list</a></span></li><li><span><a href="#5.-Now-combine-those-two-ideas-and-write-a-function-that-receives-a-list-and-either-&quot;+&quot;-or-&quot;*&quot;-and-outputs-acordingly" data-toc-modified-id="5.-Now-combine-those-two-ideas-and-write-a-function-that-receives-a-list-and-either-&quot;+&quot;-or-&quot;*&quot;-and-outputs-acordingly-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly</a></span></li><li><span><a href="#6.-Write-a-function-that-returns-the-factorial-of-a-number." data-toc-modified-id="6.-Write-a-function-that-returns-the-factorial-of-a-number.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>6. Write a function that returns the factorial of a number.</a></span></li><li><span><a href="#7.-Write-a-function-that-takes-a-list-and-returns-a-list-of-the-unique-values." data-toc-modified-id="7.-Write-a-function-that-takes-a-list-and-returns-a-list-of-the-unique-values.-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>7. Write a function that takes a list and returns a list of the unique values.</a></span></li><li><span><a href="#8.-Write-a-function-that-returns-the-mode-of-a-list,-i.e.:-the-element-that-appears-the-most-times." data-toc-modified-id="8.-Write-a-function-that-returns-the-mode-of-a-list,-i.e.:-the-element-that-appears-the-most-times.-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.</a></span></li><li><span><a href="#9.-Write-a-function-that-calculates-the-standard-deviation-of-a-list." data-toc-modified-id="9.-Write-a-function-that-calculates-the-standard-deviation-of-a-list.-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>9. Write a function that calculates the standard deviation of a list.</a></span></li><li><span><a href="#10.-Write-a-function-to-check-if-a-string-is-a-pangram,-i.e.:-if-it-contains-all-the-letters-of-the-alphabet-at-least-once.-Mind-that-the-strings-may-contain-characters-that-are-not-letters." data-toc-modified-id="10.-Write-a-function-to-check-if-a-string-is-a-pangram,-i.e.:-if-it-contains-all-the-letters-of-the-alphabet-at-least-once.-Mind-that-the-strings-may-contain-characters-that-are-not-letters.-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.</a></span></li><li><span><a href="#11.-Write-a-function-that-receives-a-string-of-comma-separated-words-and-returns-a-string-of-comma-separated-words-sorted-alphabetically." data-toc-modified-id="11.-Write-a-function-that-receives-a-string-of-comma-separated-words-and-returns-a-string-of-comma-separated-words-sorted-alphabetically.-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.</a></span></li><li><span><a href="#12.-Write-a-function-to-check-if-a-given-password-is-strong-(at-least-8-characters,-at-least-one-lower-case,-at-least-one-upper-case,-at-least-one-number-and-at-least-one-special-character).-It-should-output-True-if-strong-and-False-if-not." data-toc-modified-id="12.-Write-a-function-to-check-if-a-given-password-is-strong-(at-least-8-characters,-at-least-one-lower-case,-at-least-one-upper-case,-at-least-one-number-and-at-least-one-special-character).-It-should-output-True-if-strong-and-False-if-not.-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
#Run this cell

from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if (a > b):
        print(a," is greater than ",b)
    else:
        print(b," is greater than ",a)

# %%
# This will test your function 
test_greater(greater)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 971 : Should be 971
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -640 : Should be -640
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -40 : Should be -40
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 191 : Should be 191
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 329 : Should be 329
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 550 : Should be 550
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 200 : Should be 200
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 849 : Should be 849
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 202 : Should be 202
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 772 : Should be 772
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 644 : Should be 644
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 419 : Should be 419
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -541 : Should be -541
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 749 : Should be 749
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 373 : Should be 373
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 861 : Should be 861
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -216 : Should be -216
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 560 : Should be 560
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 862 : Should be 862
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 54 : Should be 54
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 214 : Should be 214
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 927 : Should be 927
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -33 : Should be -33
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -637 : Should be -637
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 837 : Should be 837
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -752 : Should be -752
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -67 : Should be -67
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 683 : Should be 683
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 67 : Should be 67
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -453 : Should be -453
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 680 : Should be 680
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -264 : Should be -264
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 207 : Should be 207
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 459 : Should be 459
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 909 : Should be 909
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -171 : Should be -171
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 688 : Should be 688
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 977 : Should be 977
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 246 : Should be 246
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 613 : Should be 613
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 973 : Should be 973
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 352 : Should be 352
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 280 : Should be 280
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 225 : Should be 225
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -193 : Should be -193
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 661 : Should be 661
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 881 : Should be 881
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 951 : Should be 951
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 302 : Should be 302
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 260 : Should be 260
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 710 : Should be 710
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 286 : Should be 286
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 418 : Should be 418
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -263 : Should be -263
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 261 : Should be 261
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 162 : Should be 162
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -363 : Should be -363
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 512 : Should be 512
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 977 : Should be 977
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 502 : Should be 502
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 442 : Should be 442
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 746 : Should be 746
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -152 : Should be -152
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -277 : Should be -277
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 826 : Should be 826
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 248 : Should be 248
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 637 : Should be 637
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 640 : Should be 640
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 826 : Should be 826
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -489 : Should be -489
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 848 : Should be 848
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 987 : Should be 987
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 607 : Should be 607
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 975 : Should be 975
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 471 : Should be 471
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 746 : Should be 746
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 926 : Should be 926
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 706 : Should be 706
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 811 : Should be 811
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -734 : Should be -734
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 377 : Should be 377
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 617 : Should be 617
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 921 : Should be 921
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 828 : Should be 828
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 749 : Should be 749
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 772 : Should be 772
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 172 : Should be 172
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 962 : Should be 962
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 859 : Should be 859
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 701 : Should be 701
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 460 : Should be 460
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 886 : Should be 886
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -40 : Should be -40
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 200 : Should be 200
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 876 : Should be 876
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 964 : Should be 964
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -423 : Should be -423
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != 923 : Should be 923
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: None != -145 : Should be -145
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.100s
#
# FAILED (failures=100)
# 971  is greater than  -637
# -640  is greater than  -919
# -40  is greater than  -333
# 191  is greater than  -643
# 329  is greater than  -675
# 550  is greater than  125
# 200  is greater than  -191
# 849  is greater than  764
# 202  is greater than  -213
# 772  is greater than  341
# 644  is greater than  -152
# 419  is greater than  -780
# -541  is greater than  -618
# 749  is greater than  249
# 373  is greater than  -243
# 861  is greater than  373
# -216  is greater than  -993
# 560  is greater than  -89
# 862  is greater than  497
# 54  is greater than  -875
# 214  is greater than  69
# 927  is greater than  895
# -33  is greater than  -648
# -637  is greater than  -833
# 837  is greater than  222
# -752  is greater than  -863
# -67  is greater than  -660
# 683  is greater than  -805
# 67  is greater than  -866
# -453  is greater than  -499
# 680  is greater than  -742
# -264  is greater than  -648
# 207  is greater than  128
# 459  is greater than  134
# 909  is greater than  -723
# -171  is greater than  -298
# 688  is greater than  -208
# 977  is greater than  -308
# 246  is greater than  -690
# 613  is greater than  -641
# 973  is greater than  170
# 352  is greater than  -214
# 280  is greater than  -215
# 225  is greater than  148
# -193  is greater than  -639
# 661  is greater than  514
# 881  is greater than  -689
# 951  is greater than  260
# 302  is greater than  -109
# 260  is greater than  -873
# 710  is greater than  -696
# 286  is greater than  -204
# 418  is greater than  339
# -263  is greater than  -831
# 261  is greater than  -434
# 162  is greater than  -3
# -363  is greater than  -444
# 512  is greater than  -757
# 977  is greater than  -592
# 502  is greater than  -694
# 442  is greater than  117
# 746  is greater than  296
# -152  is greater than  -879
# -277  is greater than  -888
# 826  is greater than  -633
# 248  is greater than  -497
# 637  is greater than  -587
# 640  is greater than  -837
# 826  is greater than  485
# -489  is greater than  -893
# 848  is greater than  651
# 987  is greater than  -203
# 607  is greater than  -31
# 975  is greater than  371
# 471  is greater than  297
# 746  is greater than  312
# 926  is greater than  -711
# 706  is greater than  -841
# 811  is greater than  31
# -734  is greater than  -917
# 377  is greater than  -533
# 617  is greater than  -771
# 921  is greater than  243
# 828  is greater than  647
# 749  is greater than  -77
# 772  is greater than  479
# 172  is greater than  -500
# 962  is greater than  870
# 859  is greater than  844
# 701  is greater than  168
# 460  is greater than  -696
# 886  is greater than  178
# -40  is greater than  -215
# 200  is greater than  -993
# 876  is greater than  -897
# 964  is greater than  -824
# 17  is greater than  -530
# -423  is greater than  -948
# 923  is greater than  31
# -145  is greater than  -843

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    largest = 0
    for x in range(0, len(array)):
        if(array[x] > largest):
            largest = array[x]
    return largest

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\jacob\IRONHACK2022\1.3-lab-functions\mod\testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "C:\Users\jacob\AppData\Local\Temp\ipykernel_21880\1071731921.py", line 3, in greatest
#     for x in range(0, len(array)):
# NameError: name 'array' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.114s
#
# FAILED (errors=100)

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    result=0
    for i in arr:
        result += i
    return result

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.065s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    result = 1
    for i in range(0,len(arr)):
        result = result * arr[i]
    return result

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.069s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    pass

# %%
# This will test your function 
test_operations(oper_all)

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    def factorial(x):
    if x == 1:
        return 1
    else:
        # recursive call to the function
        return (x * factorial(x-1))
# Out:
#   Cell In [15], line 3
#     if x == 1:
#     ^
# IndentationError: expected an indented block

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.072s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    uniqueElements = []
    for element in arr:
        if element not in uniqueElements:
            uniqueElements.append(element)
    return uniqueElements

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.122s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    pass

# %%
# This will test your function 
test_mode(mode_counter)

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(arr):
    pass

# %%
# This will test your function 
test_stdev(st_dev)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    pass

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    pass

# %%
# This will test your function 
test_pass(check_pass)
